# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kagglehub
#       2
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/__init__.py:4
#       1 __version__ = "1.0.1"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/colab_cache_resolver.py:5
#       2 import os
#       3 import time
# ----> 5 from kagglehub.clients import ColabClient
#       6 from kagglehub.config import is_colab_cache_disabled
#       7 from kagglehub.exceptions import BackendError, NotFoundError
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/clients.py:22
#      19 from tqdm import tqdm
#      21 import kagglehub
# ---> 22 from kagglehub.cache import delete_from_cache, get_cached_archive_path
#      23 from kagglehub.config import get_kaggle_credentials
#      24 from kagglehub.datasets_enums import KaggleDatasetAdapter
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/cache.py:6
#       3 from pathlib import Path
#       5 from kagglehub.config import get_cache_folder
# ----> 6 from kagglehub.handle import CompetitionHandle, DatasetHandle, ModelHandle, NotebookHandle, ResourceHandle
#       8 DATASETS_CACHE_SUBFOLDER = "datasets"
#       9 NOTEBOOKS_CACHE_SUBFOLDER = "notebooks"  # for resources under kaggle.com/code
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/handle.py:6
#       3 import abc
#       4 from dataclasses import asdict, dataclass
# ----> 6 from kagglesdk.kaggle_env import get_env, get_web_endpoint
#       7 from kagglesdk.models.types.model_enums import ModelFramework
#       9 from kagglehub.enum import to_enum
#
# ImportError: cannot import name 'get_web_endpoint' from 'kagglesdk.kaggle_env' (/Users/somsubhramukherjee/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglesdk/kaggle_env.py)

# %%
pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in ./my_env/lib/python3.13/site-packages (1.0.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in ./my_env/lib/python3.13/site-packages (from kagglehub) (0.1.24)
# Requirement already satisfied: packaging in ./my_env/lib/python3.13/site-packages (from kagglehub) (26.2)
# Requirement already satisfied: pyyaml in ./my_env/lib/python3.13/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in ./my_env/lib/python3.13/site-packages (from kagglehub) (2.34.2)
# Requirement already satisfied: tqdm in ./my_env/lib/python3.13/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in ./my_env/lib/python3.13/site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (7.35.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import kagglehub
#       2
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/__init__.py:4
#       1 __version__ = "1.0.1"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/colab_cache_resolver.py:5
#       2 import os
#       3 import time
# ----> 5 from kagglehub.clients import ColabClient
#       6 from kagglehub.config import is_colab_cache_disabled
#       7 from kagglehub.exceptions import BackendError, NotFoundError
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/clients.py:22
#      19 from tqdm import tqdm
#      21 import kagglehub
# ---> 22 from kagglehub.cache import delete_from_cache, get_cached_archive_path
#      23 from kagglehub.config import get_kaggle_credentials
#      24 from kagglehub.datasets_enums import KaggleDatasetAdapter
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/cache.py:6
#       3 from pathlib import Path
#       5 from kagglehub.config import get_cache_folder
# ----> 6 from kagglehub.handle import CompetitionHandle, DatasetHandle, ModelHandle, NotebookHandle, ResourceHandle
#       8 DATASETS_CACHE_SUBFOLDER = "datasets"
#       9 NOTEBOOKS_CACHE_SUBFOLDER = "notebooks"  # for resources under kaggle.com/code
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/handle.py:6
#       3 import abc
#       4 from dataclasses import asdict, dataclass
# ----> 6 from kagglesdk.kaggle_env import get_env, get_web_endpoint
#       7 from kagglesdk.models.types.model_enums import ModelFramework
#       9 from kagglehub.enum import to_enum
#
# ImportError: cannot import name 'get_web_endpoint' from 'kagglesdk.kaggle_env' (/Users/somsubhramukherjee/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglesdk/kaggle_env.py)

# %%
# !pip uninstall -y kagglehub kagglesdk
# !pip install kagglehub --upgrade
# Out:
# Found existing installation: kagglehub 1.0.1
# Uninstalling kagglehub-1.0.1:
#   Successfully uninstalled kagglehub-1.0.1
# Found existing installation: kagglesdk 0.1.24
# Uninstalling kagglesdk-0.1.24:
#   Successfully uninstalled kagglesdk-0.1.24
# Collecting kagglehub
#   Using cached kagglehub-1.0.1-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub)
#   Downloading kagglesdk-0.1.25-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in ./my_env/lib/python3.13/site-packages (from kagglehub) (26.2)
# Requirement already satisfied: pyyaml in ./my_env/lib/python3.13/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in ./my_env/lib/python3.13/site-packages (from kagglehub) (2.34.2)
# Requirement already satisfied: tqdm in ./my_env/lib/python3.13/site-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: protobuf in ./my_env/lib/python3.13/site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (7.35.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./my_env/lib/python3.13/site-packages (from requests->kagglehub) (2026.5.20)
# Using cached kagglehub-1.0.1-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.25-py3-none-any.whl (228 kB)
# Installing collected packages: kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]━ 1/2 [kagglehub]
# Successfully installed kagglehub-1.0.1 kagglesdk-0.1.25

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import kagglehub
#       2
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/__init__.py:4
#       1 __version__ = "1.0.1"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/colab_cache_resolver.py:5
#       2 import os
#       3 import time
# ----> 5 from kagglehub.clients import ColabClient
#       6 from kagglehub.config import is_colab_cache_disabled
#       7 from kagglehub.exceptions import BackendError, NotFoundError
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/clients.py:22
#      19 from tqdm import tqdm
#      21 import kagglehub
# ---> 22 from kagglehub.cache import delete_from_cache, get_cached_archive_path
#      23 from kagglehub.config import get_kaggle_credentials
#      24 from kagglehub.datasets_enums import KaggleDatasetAdapter
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/cache.py:6
#       3 from pathlib import Path
#       5 from kagglehub.config import get_cache_folder
# ----> 6 from kagglehub.handle import CompetitionHandle, DatasetHandle, ModelHandle, NotebookHandle, ResourceHandle
#       8 DATASETS_CACHE_SUBFOLDER = "datasets"
#       9 NOTEBOOKS_CACHE_SUBFOLDER = "notebooks"  # for resources under kaggle.com/code
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/handle.py:6
#       3 import abc
#       4 from dataclasses import asdict, dataclass
# ----> 6 from kagglesdk.kaggle_env import get_env, get_web_endpoint
#       7 from kagglesdk.models.types.model_enums import ModelFramework
#       9 from kagglehub.enum import to_enum
#
# ImportError: cannot import name 'get_web_endpoint' from 'kagglesdk.kaggle_env' (/Users/somsubhramukherjee/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglesdk/kaggle_env.py)

# %%
import kagglehub

path = kagglehub.dataset_download(
    "masoudnickparvar/brain-tumor-mri-dataset"
)

print(path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import kagglehub
#       2
#       3 path = kagglehub.dataset_download(
#       4     "masoudnickparvar/brain-tumor-mri-dataset"
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/__init__.py:4
#       1 __version__ = "1.0.1"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/colab_cache_resolver.py:5
#       2 import os
#       3 import time
# ----> 5 from kagglehub.clients import ColabClient
#       6 from kagglehub.config import is_colab_cache_disabled
#       7 from kagglehub.exceptions import BackendError, NotFoundError
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/clients.py:22
#      19 from tqdm import tqdm
#      21 import kagglehub
# ---> 22 from kagglehub.cache import delete_from_cache, get_cached_archive_path
#      23 from kagglehub.config import get_kaggle_credentials
#      24 from kagglehub.datasets_enums import KaggleDatasetAdapter
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/cache.py:6
#       3 from pathlib import Path
#       5 from kagglehub.config import get_cache_folder
# ----> 6 from kagglehub.handle import CompetitionHandle, DatasetHandle, ModelHandle, NotebookHandle, ResourceHandle
#       8 DATASETS_CACHE_SUBFOLDER = "datasets"
#       9 NOTEBOOKS_CACHE_SUBFOLDER = "notebooks"  # for resources under kaggle.com/code
#
# File ~/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglehub/handle.py:6
#       3 import abc
#       4 from dataclasses import asdict, dataclass
# ----> 6 from kagglesdk.kaggle_env import get_env, get_web_endpoint
#       7 from kagglesdk.models.types.model_enums import ModelFramework
#       9 from kagglehub.enum import to_enum
#
# ImportError: cannot import name 'get_web_endpoint' from 'kagglesdk.kaggle_env' (/Users/somsubhramukherjee/Desktop/jupyter/my_env/lib/python3.13/site-packages/kagglesdk/kaggle_env.py)

# %%
import zipfile

zip_path = "archive.zip"   # your zip filename
extract_path = "brain_tumor_dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2
#       3 zip_path = "archive.zip"   # your zip filename
#       4 extract_path = "brain_tumor_dataset"
#       5
# ----> 6 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       7     zip_ref.extractall(extract_path)
#       8
#       9 print("Dataset extracted successfully!")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/zipfile/__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'archive.zip'

# %%
import zipfile

zip_path = "/Users/somsubhramukherjee/Desktop/jupyter/archive.zip"   # your zip filename
extract_path = "brain_tumor_dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       2
#       3 zip_path = "/Users/somsubhramukherjee/Desktop/jupyter/archive.zip"   # your zip filename
#       4 extract_path = "brain_tumor_dataset"
#       5
# ----> 6 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#       7     zip_ref.extractall(extract_path)
#       8
#       9 print("Dataset extracted successfully!")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/zipfile/__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/somsubhramukherjee/Desktop/jupyter/archive.zip'

# %%
import os

print(os.getcwd())
# Out:
# /Users/somsubhramukherjee/Desktop/jupyter

# %%
print(os.listdir())
# Out:
# ['brain_pimple.ipynb', 'archive', '.ipynb_checkpoints', 'my_env']

# %%
import tensorflow as tf

train_dataset = tf.keras.utils.image_dataset_from_directory(
    "archive/Training",
    image_size=(224, 224),
    batch_size=32
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    "archive/Testing",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 5600 files belonging to 4 classes.
# Found 1600 files belonging to 4 classes.

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in ./my_env/lib/python3.13/site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in ./my_env/lib/python3.13/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./my_env/lib/python3.13/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in ./my_env/lib/python3.13/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in ./my_env/lib/python3.13/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in ./my_env/lib/python3.13/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in ./my_env/lib/python3.13/site-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in ./my_env/lib/python3.13/site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in ./my_env/lib/python3.13/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./my_env/lib/python3.13/site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (2.4.6)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in ./my_env/lib/python3.13/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in ./my_env/lib/python3.13/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./my_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./my_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (3.16)
# Requirement already satisfied: urllib3<3,>=1.26 in ./my_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./my_env/lib/python3.13/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./my_env/lib/python3.13/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in ./my_env/lib/python3.13/site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in ./my_env/lib/python3.13/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in ./my_env/lib/python3.13/site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./my_env/lib/python3.13/site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./my_env/lib/python3.13/site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./my_env/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf

train_dataset = tf.keras.utils.image_dataset_from_directory(
    "archive/Training",
    image_size=(224, 224),
    batch_size=32
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    "archive/Testing",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 5600 files belonging to 4 classes.
# Found 1600 files belonging to 4 classes.

# %%
print(train_dataset.class_names)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))

for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(train_dataset.class_names[labels[i]])
        plt.axis("off")

# %%
train_dataset = train_dataset.map(
    lambda x, y: (x / 255.0, y)
)

test_dataset = test_dataset.map(
    lambda x, y: (x / 255.0, y)
)

# %%
tf.__version__
# Out:
# '2.21.0'

# %%
from tensorflow import keras

# %%
keras.__version__
# Out:
# '3.14.1'

# %%
from tensorflow import keras
import tensorflow as tf

# %%
train_ds = keras.utils.image_dataset_from_directory(
    "archive/Training",
    image_size=(224, 224),
    batch_size=32
)

test_ds = keras.utils.image_dataset_from_directory(
    "archive/Testing",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 5600 files belonging to 4 classes.
# Found 1600 files belonging to 4 classes.

# %%
import numpy as np

X_train = []
y_train = []

class_names = train_ds.class_names

# %%
for images, labels in train_ds:
    X_train.append(images.numpy())
    y_train.append(labels.numpy())

X_train = np.concatenate(X_train)
y_train = np.concatenate(y_train)

# %%
X_test = []
y_test = []

for images, labels in test_ds:
    X_test.append(images.numpy())
    y_test.append(labels.numpy())

X_test = np.concatenate(X_test)
y_test = np.concatenate(y_test)

# %%
X_train.shape
# Out:
# (5600, 224, 224, 3)

# %%
X_test.shape
# Out:
# (1600, 224, 224, 3)

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
import numpy as np
np.unique(y_train)
# Out:
# array([0, 1, 2, 3], dtype=int32)

# %%
train_ds.class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
import numpy as np

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

print(X_train_flat.shape)
# Out:
# (5600, 150528)

# %%
model = keras.models.Sequential()
#input layer
model.add(keras.layers.Flatten(input_shape=[224, 224, 3]))
#hidden layers
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
#output layer
model.add(keras.layers.Dense(4, activation="softmax"))
# Out:
# /Users/somsubhramukherjee/Desktop/jupyter/my_env/lib/python3.13/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300)            │    45,158,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           404 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,189,204 (172.38 MB)
#  Trainable params: 45,189,204 (172.38 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.layers
# Out:
# [<Flatten name=flatten, built=True>,
#  <Dense name=dense, built=True>,
#  <Dense name=dense_1, built=True>,
#  <Dense name=dense_2, built=True>]

# %%
model.compile(loss="sparse_categorical_crossentropy",
optimizer="sgd",
metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
validation_data=(X_valid, y_valid))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 history = model.fit(X_train, y_train, epochs=30,
# ----> 2 validation_data=(X_valid, y_valid))
#
# NameError: name 'X_valid' is not defined

# %%
history = model.fit(X_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.5041 - loss: 1.1192
# Epoch 2/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.6696 - loss: 0.8200
# Epoch 3/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.7200 - loss: 0.6931
# Epoch 4/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.7507 - loss: 0.6249
# Epoch 5/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.7743 - loss: 0.5670
# Epoch 6/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.7987 - loss: 0.5114
# Epoch 7/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.8175 - loss: 0.4647
# Epoch 8/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.8352 - loss: 0.4252
# Epoch 9/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 41ms/step - accuracy: 0.8605 - loss: 0.3678
# Epoch 10/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.8671 - loss: 0.3543
# Epoch 11/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.8796 - loss: 0.3167
# Epoch 12/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.8957 - loss: 0.2819
# Epoch 13/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - accuracy: 0.8934 - loss: 0.2805
# Epoch 14/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9129 - loss: 0.2415
# Epoch 15/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9234 - loss: 0.2126
# Epoch 16/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9354 - loss: 0.1835
# Epoch 17/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9236 - loss: 0.2171
# Epoch 18/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9521 - loss: 0.1534
# Epoch 19/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9500 - loss: 0.1459
# Epoch 20/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.9580 - loss: 0.1319
# Epoch 21/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9675 - loss: 0.0958
# Epoch 22/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9445 - loss: 0.1757
# Epoch 23/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9755 - loss: 0.0907
# Epoch 24/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9704 - loss: 0.1050
# Epoch 25/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9686 - loss: 0.1052
# Epoch 26/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.9807 - loss: 0.0654
# Epoch 27/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9880 - loss: 0.0492
# Epoch 28/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9882 - loss: 0.0477
# Epoch 29/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9916 - loss: 0.0368
# Epoch 30/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9955 - loss: 0.0268

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8263 - loss: 1.0318
# [1.0317782163619995, 0.8262500166893005]

# %%
model.evaluate(X_train, y_train)
# Out:
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9977 - loss: 0.0212
# [0.02115618996322155, 0.9976785778999329]

# %%
model = keras.models.Sequential()
#input layer
model.add(keras.layers.Flatten(input_shape=[224, 224, 3]))
#hidden layers
model.add(keras.layers.Dense(100, activation="relu", kernel_initializer="he_normal",
kernel_regularizer=keras.regularizers.l2(0.01))),
model.add(keras.layers.Dropout(rate=0.2)),
model.add(keras.layers.Dense(50, activation="relu", kernel_initializer="he_normal",
kernel_regularizer=keras.regularizers.l2(0.01))),
model.add(keras.layers.Dropout(rate=0.2)),
#output layer
model.add(keras.layers.Dense(4, activation="softmax"))
# Out:
# /Users/somsubhramukherjee/Desktop/jupyter/my_env/lib/python3.13/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 150528)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 100)            │    15,052,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           204 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,058,154 (57.44 MB)
#  Trainable params: 15,058,154 (57.44 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.layers
# Out:
# [<Flatten name=flatten_1, built=True>,
#  <Dense name=dense_3, built=True>,
#  <Dropout name=dropout, built=True>,
#  <Dense name=dense_4, built=True>,
#  <Dropout name=dropout_1, built=True>,
#  <Dense name=dense_5, built=True>]

# %%
model.compile(loss="sparse_categorical_crossentropy",
optimizer="sgd",
metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30,
validation_data=(X_valid, y_valid))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 history = model.fit(X_train, y_train, epochs=30,
# ----> 2 validation_data=(X_valid, y_valid))
#
# NameError: name 'X_valid' is not defined

# %%
history = model.fit(X_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.4225 - loss: 4.1578
# Epoch 2/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.5584 - loss: 3.7151
# Epoch 3/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.6080 - loss: 3.4456
# Epoch 4/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.6520 - loss: 3.2058
# Epoch 5/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.6661 - loss: 3.0273
# Epoch 6/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.6936 - loss: 2.8205
# Epoch 7/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7000 - loss: 2.6831
# Epoch 8/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.6868 - loss: 2.5836
# Epoch 9/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7262 - loss: 2.3814
# Epoch 10/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7332 - loss: 2.2775
# Epoch 11/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7436 - loss: 2.1436
# Epoch 12/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7373 - loss: 2.0555
# Epoch 13/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7563 - loss: 1.9304
# Epoch 14/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7643 - loss: 1.8258
# Epoch 15/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7513 - loss: 1.7792
# Epoch 16/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.7634 - loss: 1.6871
# Epoch 17/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7779 - loss: 1.5974
# Epoch 18/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7811 - loss: 1.5305
# Epoch 19/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7798 - loss: 1.4944
# Epoch 20/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7796 - loss: 1.4070
# Epoch 21/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7771 - loss: 1.3661
# Epoch 22/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7837 - loss: 1.3052
# Epoch 23/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7546 - loss: 1.3468
# Epoch 24/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.7420 - loss: 1.3239
# Epoch 25/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.6812 - loss: 1.4042
# Epoch 26/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.6837 - loss: 1.3567
# Epoch 27/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.6973 - loss: 1.2885
# Epoch 28/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.6561 - loss: 1.3602
# Epoch 29/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.6527 - loss: 1.3412
# Epoch 30/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7293 - loss: 1.1440

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6806 - loss: 1.4936
# [1.4935564994812012, 0.6806250214576721]

# %%
model.evaluate(X_train, y_train)
# Out:
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8464 - loss: 0.9546
# [0.9545974135398865, 0.8464285731315613]

# %%
model = keras.models.Sequential()

model.add(keras.layers.Resizing(64, 64))
model.add(keras.layers.Flatten(input_shape=[64, 64, 3]))

# Hidden layers
model.add(keras.layers.Dense(128, activation="relu",
                             kernel_initializer="he_normal",
                             kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(keras.layers.Dropout(0.4))

model.add(keras.layers.Dense(64, activation="relu",
                             kernel_initializer="he_normal",
                             kernel_regularizer=keras.regularizers.l2(0.001)))
model.add(keras.layers.Dropout(0.4))

model.add(keras.layers.Dense(32, activation="relu"))

# Output layer
model.add(keras.layers.Dense(4, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing_2 (Resizing)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.layers
# Out:
# [<Resizing name=resizing_2, built=False>,
#  <Flatten name=flatten_4, built=False>,
#  <Dense name=dense_14, built=False>,
#  <Dropout name=dropout_6, built=True>,
#  <Dense name=dense_15, built=False>,
#  <Dropout name=dropout_7, built=True>,
#  <Dense name=dense_16, built=False>,
#  <Dense name=dense_17, built=False>]

# %%
model.compile(loss="sparse_categorical_crossentropy",
optimizer="sgd",
metrics=["accuracy"])

# %%
model.compile(loss="sparse_categorical_crossentropy",
optimizer="adam",
metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3814 - loss: 1.5818
# Epoch 2/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5157 - loss: 1.2240
# Epoch 3/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5834 - loss: 1.0606
# Epoch 4/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5909 - loss: 1.0252
# Epoch 5/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5807 - loss: 1.0080
# Epoch 6/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6100 - loss: 0.9472
# Epoch 7/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6225 - loss: 0.9244
# Epoch 8/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6166 - loss: 0.9420
# Epoch 9/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6336 - loss: 0.9100
# Epoch 10/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6586 - loss: 0.8652
# Epoch 11/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6429 - loss: 0.8984
# Epoch 12/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6668 - loss: 0.8482
# Epoch 13/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6570 - loss: 0.8663
# Epoch 14/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6438 - loss: 0.8746
# Epoch 15/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6054 - loss: 0.9343
# Epoch 16/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6066 - loss: 0.9262
# Epoch 17/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6098 - loss: 0.9219
# Epoch 18/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6054 - loss: 0.9261
# Epoch 19/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5979 - loss: 0.9286
# Epoch 20/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6241 - loss: 0.8861
# Epoch 21/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6289 - loss: 0.9015
# Epoch 22/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6432 - loss: 0.8598
# Epoch 23/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6321 - loss: 0.8814
# Epoch 24/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.5604 - loss: 0.9902
# Epoch 25/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6091 - loss: 0.9106
# Epoch 26/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6398 - loss: 0.8951
# Epoch 27/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6543 - loss: 0.8606
# Epoch 28/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6618 - loss: 0.8525
# Epoch 29/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6371 - loss: 0.8760
# Epoch 30/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6482 - loss: 0.8726

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6381 - loss: 1.2106
# [1.2105846405029297, 0.6381250023841858]

# %%
model.evaluate(X_train, y_train)
# Out:
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6820 - loss: 0.7289
# [0.7289325594902039, 0.6819642782211304]

# %%
base_model = keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 8s 1us/step

# %%
model = keras.Sequential([
    base_model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(4, activation="softmax")
])

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 181ms/step - accuracy: 0.8030 - loss: 0.5118
# Epoch 2/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 180ms/step - accuracy: 0.8864 - loss: 0.2998
# Epoch 3/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 190ms/step - accuracy: 0.9046 - loss: 0.2470
# Epoch 4/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 189ms/step - accuracy: 0.9229 - loss: 0.2159
# Epoch 5/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9345 - loss: 0.1754
# Epoch 6/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9391 - loss: 0.1545
# Epoch 7/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9434 - loss: 0.1469
# Epoch 8/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9534 - loss: 0.1224
# Epoch 9/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9577 - loss: 0.1133
# Epoch 10/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9614 - loss: 0.1037
# Epoch 11/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9609 - loss: 0.1029
# Epoch 12/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 187ms/step - accuracy: 0.9648 - loss: 0.0895
# Epoch 13/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9696 - loss: 0.0782
# Epoch 14/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9743 - loss: 0.0714
# Epoch 15/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9779 - loss: 0.0607
# Epoch 16/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9695 - loss: 0.0796
# Epoch 17/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9757 - loss: 0.0631
# Epoch 18/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9777 - loss: 0.0616
# Epoch 19/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 185ms/step - accuracy: 0.9800 - loss: 0.0534
# Epoch 20/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 190ms/step - accuracy: 0.9821 - loss: 0.0498
# Epoch 21/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 191ms/step - accuracy: 0.9802 - loss: 0.0535
# Epoch 22/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 189ms/step - accuracy: 0.9852 - loss: 0.0436
# Epoch 23/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 189ms/step - accuracy: 0.9855 - loss: 0.0431
# Epoch 24/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9886 - loss: 0.0358
# Epoch 25/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9804 - loss: 0.0509
# Epoch 26/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9855 - loss: 0.0418
# Epoch 27/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9786 - loss: 0.0535
# Epoch 28/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.9879 - loss: 0.0346
# Epoch 29/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9873 - loss: 0.0372
# Epoch 30/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 33s 186ms/step - accuracy: 0.9820 - loss: 0.0474

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 173ms/step - accuracy: 0.9237 - loss: 0.8035
# [0.8035077452659607, 0.9237499833106995]

# %%
model.evaluate(X_train, y_train)
# Out:
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 31s 175ms/step - accuracy: 0.9982 - loss: 0.0085
# [0.008544252254068851, 0.9982143044471741]

# %%
model.evaluate(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.evaluate(X_train, y_train)
#
# NameError: name 'model' is not defined

# %%
base_model = keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = True

# %%
for layer in base_model.layers[:-30]:
    layer.trainable = False

# %%
model = keras.Sequential([
    base_model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(4, activation="softmax")
])

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %%
history = model.fit(X_train, y_train, epochs=30)
# Out:
# Epoch 1/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 44s 235ms/step - accuracy: 0.8841 - loss: 0.3333
# Epoch 2/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 43s 245ms/step - accuracy: 0.9380 - loss: 0.1946
# Epoch 3/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 45s 255ms/step - accuracy: 0.9563 - loss: 0.1324
# Epoch 4/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 46s 259ms/step - accuracy: 0.9654 - loss: 0.1109
# Epoch 5/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 46s 265ms/step - accuracy: 0.9727 - loss: 0.0851
# Epoch 6/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 46s 265ms/step - accuracy: 0.9718 - loss: 0.0842
# Epoch 7/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 268ms/step - accuracy: 0.9802 - loss: 0.0562
# Epoch 8/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 267ms/step - accuracy: 0.9834 - loss: 0.0513
# Epoch 9/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 266ms/step - accuracy: 0.9814 - loss: 0.0663
# Epoch 10/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 266ms/step - accuracy: 0.9816 - loss: 0.0610
# Epoch 11/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 269ms/step - accuracy: 0.9882 - loss: 0.0334
# Epoch 12/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 46s 265ms/step - accuracy: 0.9918 - loss: 0.0234
# Epoch 13/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 46s 265ms/step - accuracy: 0.9880 - loss: 0.0408
# Epoch 14/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 270ms/step - accuracy: 0.9920 - loss: 0.0247
# Epoch 15/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 270ms/step - accuracy: 0.9880 - loss: 0.0380
# Epoch 16/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 275ms/step - accuracy: 0.9950 - loss: 0.0151
# Epoch 17/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 275ms/step - accuracy: 0.9920 - loss: 0.0322
# Epoch 18/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 49s 277ms/step - accuracy: 0.9925 - loss: 0.0259
# Epoch 19/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 276ms/step - accuracy: 0.9905 - loss: 0.0327
# Epoch 20/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 276ms/step - accuracy: 0.9921 - loss: 0.0249
# Epoch 21/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 270ms/step - accuracy: 0.9939 - loss: 0.0240
# Epoch 22/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 267ms/step - accuracy: 0.9943 - loss: 0.0186
# Epoch 23/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 272ms/step - accuracy: 0.9905 - loss: 0.0313
# Epoch 24/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 269ms/step - accuracy: 0.9952 - loss: 0.0186
# Epoch 25/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 266ms/step - accuracy: 0.9923 - loss: 0.0243
# Epoch 26/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 47s 269ms/step - accuracy: 0.9954 - loss: 0.0220
# Epoch 27/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 273ms/step - accuracy: 0.9948 - loss: 0.0185
# Epoch 28/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 275ms/step - accuracy: 0.9966 - loss: 0.0120
# Epoch 29/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 48s 275ms/step - accuracy: 0.9970 - loss: 0.0131
# Epoch 30/30
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 292s 2s/step - accuracy: 0.9959 - loss: 0.0110

# %%
model.evaluate(X_test, y_test)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.9281 - loss: 1.3915
# [1.3915290832519531, 0.9281250238418579]

# %%
model.evaluate(X_train, y_train)
# Out:
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 32s 179ms/step - accuracy: 0.9929 - loss: 0.0536
# [0.053574301302433014, 0.9928571581840515]

# %%
model.save("brain_tumor_classifier.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("brain_tumor_classifier.keras")

# %%
train_ds.class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']
